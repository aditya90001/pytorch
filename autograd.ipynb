# %%
import torch

# %%
a=torch.tensor(3.0,requires_grad=True)## if you want to find any derivative of any tensor use reqiures_grad=True

# %%
y=a**2

# %%
a
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()# dy/dx nikalata hain

# %%
a.grad
# Out:
# tensor(6.)

# %%
## now lets do some complex
x=torch.tensor(3.0,requires_grad=True)

# %%
y=x**2

# %%
z=torch.sin(y)

# %%
#now i have to find dz/dx
print(x,y,z)
# Out:
# tensor(3., requires_grad=True) tensor(9., grad_fn=<PowBackward0>) tensor(0.4121, grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-5.4668)
